# %% [markdown]
# # EmotionRadar — Full Pipeline
# **Assembled by: everyone | Final week only**
#
# ## What this notebook does
# This is the consolidated notebook for submission and presentation.
# All cells from 01–05 are copied here in order, cleaned up.
# Do not edit this file until May 15.
#
# ## How to run
# Pull latest. Run all cells top to bottom.
# All data and models are in the repo — no setup needed.
