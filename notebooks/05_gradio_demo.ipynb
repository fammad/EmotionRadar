# %% [markdown]
# # 05 — Interactive Demo
# **Owner: Fuad | Status:  Waiting on 02**
#
# ## What this notebook does
# - Loads TF-IDF + LogReg model from data/models/
# - Gradio interface with two outputs:
#   1. Radar chart — 7 emotion probability scores
#   2. Word highlighting — each word colored by dominant emotion signal
#      (weights pulled from LogReg coefficients)
# - Runs inline: demo.launch(inline=True)
#
# ## Input files (already in repo — just pull)
# - data/models/tfidf.pkl
# - data/models/lr_model.pkl
#
# ## How to run
# Pull latest from GitHub. Run cells top to bottom.
# For presentation: run last cell, demo launches inside the notebook.
